# %%
import sys
import os

root_dir = os.path.split(os.getcwd())[0]

sys.path.append(root_dir)
from utils.helper_metastore import *
from utils.configurations.config import Config

# %%
import warnings
warnings.filterwarnings('ignore', 'absl')

# %load_ext tensorboard

# %% [markdown]
# ## Model Training

# %% [markdown]
# Here comes the most important part of our pipeline (model training). The whole pipeline that we are trying to build on are jointly called as an Continous training component in the MLOps workflow. The main moto over here is to keep our model upto date in the production and the counter back the data drift, model drift and training-serving skew.
#
# ![mlops pipeline](image/MLOps_pipeline.svg)

# %% [markdown]
# In this notebook, we cover the model training process as part of a machine learning pipeline, including how it is automated in a TFX pipeline. We also include some details of distribution strategies available in TensorFlow and how to tune hyperparameters in a pipeline. This chapter is more specific to TFX pipelines than most of the
# others because we don’t cover training as a standalone process.
#
# One very important feature of training a model in a TFX pipeline is that the data pre-processing step which ar saved along with the trained model weights. This is very useful once our model is deployed to production because it means that the preprocessing steps will always produce the features the models expecting. Without this feature, it would be possible to update the data pre‐processing steps without updating the model, and then the model would fail in production. So why TFX eports the proprocessing steps and the model as one graph, this potentialy eliminates the source of error.

# %%
from ml_metadata.metadata_store import metadata_store
from ml_metadata.proto import metadata_store_pb2
import tensorflow as tf

base_dir = os.path.join(root_dir, Config.PIPELINE_FOLDER)
file = [i for i in os.listdir(base_dir) if 'sqlite' in i]
config = os.path.join(base_dir, file[0])

connection_config = metadata_store_pb2.ConnectionConfig()
connection_config.sqlite.filename_uri = config

store = metadata_store.MetadataStore(connection_config)

# %%
previous_execution_status = get_latest_executions(store, Config.PIPELINE_NAME, 'Transform')

if previous_execution_status:
    previous_execution_status = previous_execution_status[0].last_known_state
else:
    raise Exception('[Exception] Run the Data Ingestion Notebook before Running this...') 
    
if  previous_execution_status == 3:
    print('[INFO] previous component Execution State is Success. You can Proceed Further now..')
elif previous_execution_status == 2:
    print('[Warning] previous component Execution is in Running State')
# Out:
# [INFO] previous component Execution State is Success. You can Proceed Further now..

# %% [markdown]
# ## Defining the model

# %% [markdown]
# In this session, let assume we created some model which was trained on offline experimentation. we then decided to productionize it with the MLOps worflow. In this pipeline step, we want to export the model with our preprocessing steps, we need to guarantee that the model input names match the transformed feature names from ```preprocessing_fn()```. In our example model, we reuse the ```transformed_name()``` function to add the suffix _xf to our features.

# %%
# %%writefile ../script/module.py

import tensorflow_transform as tft
import tensorflow as tf
import tensorflow_hub as hub
import sys
import os

root_dir = os.path.split(os.getcwd())[0]

sys.path.append(root_dir)
from utils.configurations.config import Config


def transformed_name(key):
    return key + '_xf'


def get_model():
    LABEL_KEY = "consumer_disputed"
    # Loop over the features and create an input for each feature.
    # Feature name, feature dimensionality.
    ONE_HOT_FEATURES = {
    "product": 11,
    "sub_product": 45,
    "company_response": 5,
    "state": 60,
    "issue": 90
    }

    # Feature name, bucket count.
    BUCKET_FEATURES = {
    "zip_code": 10
    }

    # Feature name, value is unused.
    TEXT_FEATURES = {
    "consumer_complaint_narrative": None
    }
    # One-hot categorical features
    input_features = []
    for key, dim in ONE_HOT_FEATURES.items():
        input_features.append(
            tf.keras.Input(shape=(dim + 1,),
            name=transformed_name(key)))
        
    # Adding bucketized features
    for key, dim in BUCKET_FEATURES.items():
        input_features.append(
            tf.keras.Input(shape=(dim + 1,),
            name=transformed_name(key)))
    
    # Adding text input features
    input_texts = []
    for key in TEXT_FEATURES.keys():
        input_texts.append(
            tf.keras.Input(shape=(1,),
            name=transformed_name(key),
            dtype=tf.string))
    
    inputs = input_features + input_texts
    # Embed text features
    # Load the tf.hub module of the Universal Sentence Encoder model.
    MODULE_URL = Config.UNIVERSAL_EMBEDDING_MODEL
    embed = hub.KerasLayer(MODULE_URL)
    
    reshaped_narrative = tf.reshape(input_texts[0], [-1]) # Keras inputs are two-dimensional, 
                                                            # but the encoder expects one-dimensional inputs.
    embed_narrative = embed(reshaped_narrative)
    deep_ff = tf.keras.layers.Reshape((512, ), input_shape=(1, 512))(embed_narrative)
    deep = tf.keras.layers.Dense(256, activation='relu')(deep_ff)
    deep = tf.keras.layers.Dense(64, activation='relu')(deep)
    deep = tf.keras.layers.Dense(16, activation='relu')(deep)
    wide_ff = tf.keras.layers.concatenate(input_features)
    wide = tf.keras.layers.Dense(16, activation='relu')(wide_ff)
    both = tf.keras.layers.concatenate([deep, wide])
    output = tf.keras.layers.Dense(1, activation='sigmoid')(both)
    keras_model = tf.keras.models.Model(inputs, output)
    keras_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
                    loss='binary_crossentropy',
                    metrics=[
                        tf.keras.metrics.BinaryAccuracy(),
                        tf.keras.metrics.TruePositives()
                    ])
    return keras_model
# Out:
# Overwriting ../script/module.py

# %% [markdown]
# ## TFX Trainer Component
#
# The TFX Trainer component handles the training step in our pipeline. the Trainer component will produce a model that will be put into production.The Transform steps will be included in this model, the data preprocessing steps will always match what the model is expecting. This removes a huge potential source of errors when our model is deployed.
#
# In our example project, the Trainer component requires the following inputs:
# - The previously generated data schema, generated by the data validation step
# - The transformed data and its preprocessing graph
# - Training parameters (e.g., the number of training steps)
# - A module file containing a run_fn() function, which defines the training process

# %% [markdown]
# ### run_fn() Function
#
# The Trainer component will look for a run_fn() function in our module file and use the function as an entry point to execute the training process. The module file needs The TFX Trainer Component to be accessible to the Trainer component. If we run the component in an interactive context, we can simply define the absolute path to the module file and pass it to the component. If you run your pipelines in production it will differ. It will be convered in the later notebook.
#
# The run_fn() function is a generic entry point to the training steps and not tf.Keras specific. It carries out the following steps:
# - Loading the training and validation data (or the data generator)
# - Defining the model architecture and compiling the model
# - Training the model
# - Exporting the model to be evaluated in the next pipeline step

# %%
# %%writefile ../script/module.py -a
#
#
# def run_fn(fn_args):
#     tf_transform_output = tft.TFTransformOutput(fn_args.transform_output) # line 1
#     train_dataset = input_fn(fn_args.train_files, tf_transform_output) # line 2
#     eval_dataset = input_fn(fn_args.eval_files, tf_transform_output) # line 3
#     model = get_model() # line 4
#     log_dir = os.path.join(os.path.dirname(fn_args.serving_model_dir), 'logs')
#     tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, update_freq='batch') # line 5
#     model.fit(
#         train_dataset,
#         steps_per_epoch=fn_args.train_steps,
#         validation_data=eval_dataset,
#         validation_steps=fn_args.eval_steps,
#         callbacks=[tensorboard_callback])  # line 6
#
#     signatures = {
#     'serving_default':
#     get_serve_tf_examples_fn(model,tf_transform_output).get_concrete_function(
#             tf.TensorSpec(
#             shape=[None],
#             dtype=tf.string,
#             name='examples')
#             )
#     } # line 7
#
#     model.save(fn_args.serving_model_dir, save_format='tf', signatures=signatures) # line 8
# Out:
# Appending to ../script/module.py

# %% [markdown]
# Line 1, 2, 3
#
# The ```run_fn``` function receives a set of arguments, including the transform graph, example datasets, and training parameters through the fn_args object.
#
# Loading data for model training and validation is performed in batches, and the loading is handled by the ```input_fn()``` function.

# %%
# %%writefile ../script/module.py -a
#
# LABEL_KEY = 'consumer_disputed'
# def _gzip_reader_fn(filenames):
#     return tf.data.TFRecordDataset(filenames, compression_type='GZIP')
#
#
# def input_fn(file_pattern,
#     tf_transform_output, batch_size=32):
#     transformed_feature_spec = (
#     tf_transform_output.transformed_feature_spec().copy())
#     dataset = tf.data.experimental.make_batched_features_dataset(
#         file_pattern=file_pattern,
#         batch_size=batch_size,
#         features=transformed_feature_spec,
#         reader=_gzip_reader_fn,
#         label_key=transformed_name(LABEL_KEY))
#     return dataset
# Out:
# Appending to ../script/module.py

# %% [markdown]
# The input_fn function lets us load the compressed, preprocessed datasets that were generated by the previous Transform step. To do this, we need to pass the tf_transform_output to the function. This gives us the data schema to load the dataset from the TFRecord data structures generated by the Transform component. By using the
# preprocessed datasets, we can avoid data preprocessing during training and speed up the training process.
#
#
# The ```input_fn``` returns a generator which created using the ```batched_features_dataset``` function that will supply data to the model one batch at a time.

# %% [markdown]
# **<u>line 4, 6</u>**
#
# Now that we have defined our data-loading steps, the next step is defining our model architecture and compiling our model. In our run_fn , this will require a call to get_model() (line 4),
#
#
# Next, we train our compiled tf.Keras model with the Keras method fit() (line 6)
#
# Once the model training is complete, the next step is to export the trained model. we want to define how the preprocessing steps has to be exported with the model.
#
# In line 7, we define the model signature and saved the model

# %% [markdown]
# The ```run_fn()``` exports the ```get_serve_tf_examples_fn``` as part of the model signature. When a model has been exported and deployed, every prediction request will pass through the ```serve_tf_examples_fn()```
#
# With every request, we parse the serialized tf.Example records and apply the preprocessing steps to the raw
# request data. The model then makes a prediction on the preprocessed data.

# %%
# %%writefile ../script/module.py -a
#
# def get_serve_tf_examples_fn(model, tf_transform_output):
#     model.tft_layer = tf_transform_output.transform_features_layer() # Load the preprocessing graph
#
#     @tf.function
#     def serve_tf_examples_fn(serialized_tf_examples):
#         feature_spec = tf_transform_output.raw_feature_spec()
#         feature_spec.pop(LABEL_KEY)
#         # Parse the raw tf.Example records from the request.
#         parsed_features = tf.io.parse_example(serialized_tf_examples, feature_spec)
#         # Apply the preprocessing transformation to raw data.
#         transformed_features = model.tft_layer(parsed_features)
#         # Perform prediction with preprocessed data.
#         outputs = model(transformed_features)
#         return {'outputs': outputs}
#     return serve_tf_examples_fn
# Out:
# Appending to ../script/module.py

# %% [markdown]
# ## Running the Trainer Component

# %%
from tfx.types import channel_utils
from tfx.types import standard_artifacts
from tfx.orchestration.experimental.interactive.interactive_context import InteractiveContext
from tfx.components import Trainer
from tfx.components.base import executor_spec
from tfx.components.trainer.executor import GenericExecutor
from tfx.proto import trainer_pb2

# %%
artifacts = get_latest_artifacts(store, Config.PIPELINE_NAME, 'SchemaGen')
example_schema = find_latest_artifacts_by_type(store, artifacts, standard_artifacts.Schema.TYPE_NAME)
example_schema = channel_utils.as_channel(example_schema)

# %%
artifacts = get_latest_artifacts(store, Config.PIPELINE_NAME, 'Transform')
transform_examples = find_latest_artifacts_by_type(store, artifacts, standard_artifacts.Examples.TYPE_NAME)
transform_examples = channel_utils.as_channel(transform_examples)

transform_graph = find_latest_artifacts_by_type(store, artifacts, standard_artifacts.TransformGraph.TYPE_NAME)
transform_graph = channel_utils.as_channel(transform_graph)

# %%
TRAINING_STEPS = 1000
EVALUATION_STEPS = 100

trainer = Trainer(
    module_file="../script/module.py",
    custom_executor_spec=executor_spec.ExecutorClassSpec(GenericExecutor),
    transformed_examples=transform_examples,
    transform_graph=transform_graph,
    schema=example_schema,
    train_args=trainer_pb2.TrainArgs(num_steps=TRAINING_STEPS),
    eval_args=trainer_pb2.EvalArgs(num_steps=EVALUATION_STEPS))
# Out:
# WARNING:absl:From <ipython-input-11-feada9b2400c>:6: The name tfx.components.base.executor_spec.ExecutorClassSpec is deprecated. Please use tfx.dsl.components.base.executor_spec.ExecutorClassSpec instead.

# %%
pipeline_name = Config.PIPELINE_NAME
base_root = os.path.split(os.getcwd())[0]
pipeline_root = os.path.join(base_root, f'temp_')
beam_args = [
    '--runner=DirectRunner'
]

if not os.path.exists(pipeline_root):
    raise Exception('Please do follow the notebook sequence')

context = InteractiveContext(pipeline_name = pipeline_name,
                            pipeline_root = pipeline_root,
                            beam_pipeline_args = beam_args)

context.run(trainer)
# Out:
# WARNING:absl:InteractiveContext metadata_connection_config not provided: using SQLite ML Metadata database at /home/jagan-ds/Documents/Tensorflow-Extended-tutorial/temp_/metadata.sqlite.
# WARNING:absl:Examples artifact does not have payload_format custom property. Falling back to FORMAT_TF_EXAMPLE
# WARNING:absl:Examples artifact does not have payload_format custom property. Falling back to FORMAT_TF_EXAMPLE
#  108/1000 [==>...........................] - ETA: 4:28:54 - loss: 0.6927 - binary_accuracy: 0.5000 - true_positives: 3.000 - ETA: 15:15 - loss: 0.6957 - binary_accuracy: 0.4844 - true_positives: 3.5000  - ETA: 21:03 - loss: 0.6916 - binary_accuracy: 0.5104 - true_positives: 4.333 - ETA: 14:34 - loss: 0.6878 - binary_accuracy: 0.5352 - true_positives: 4.750 - ETA: 11:13 - loss: 0.6870 - binary_accuracy: 0.5494 - true_positives: 5.000 - ETA: 9:14 - loss: 0.6857 - binary_accuracy: 0.5628 - true_positives: 5.166 - ETA: 7:53 - loss: 0.6835 - binary_accuracy: 0.5762 - true_positives: 5.28 - ETA: 6:55 - loss: 0.6807 - binary_accuracy: 0.5896 - true_positives: 5.37 - ETA: 6:15 - loss: 0.6778 - binary_accuracy: 0.6013 - true_positives: 5.44 - ETA: 5:43 - loss: 0.6759 - binary_accuracy: 0.6096 - true_positives: 5.50 - ETA: 5:16 - loss: 0.6741 - binary_accuracy: 0.6164 - true_positives: 5.54 - ETA: 4:56 - loss: 0.6713 - binary_accuracy: 0.6238 - true_positives: 5.58 - ETA: 4:38 - loss: 0.6681 - binary_accuracy: 0.6311 - true_positives: 5.61 - ETA: 4:23 - loss: 0.6649 - binary_accuracy: 0.6379 - true_positives: 5.64 - ETA: 4:11 - loss: 0.6619 - binary_accuracy: 0.6440 - true_positives: 5.66 - ETA: 3:59 - loss: 0.6590 - binary_accuracy: 0.6495 - true_positives: 5.68 - ETA: 3:50 - loss: 0.6562 - binary_accuracy: 0.6545 - true_positives: 5.70 - ETA: 3:42 - loss: 0.6533 - binary_accuracy: 0.6593 - true_positives: 5.72 - ETA: 3:33 - loss: 0.6506 - binary_accuracy: 0.6636 - true_positives: 5.73 - ETA: 3:26 - loss: 0.6484 - binary_accuracy: 0.6673 - true_positives: 5.75 - ETA: 3:20 - loss: 0.6464 - binary_accuracy: 0.6706 - true_positives: 5.76 - ETA: 3:14 - loss: 0.6446 - binary_accuracy: 0.6736 - true_positives: 5.77 - ETA: 3:09 - loss: 0.6434 - binary_accuracy: 0.6761 - true_positives: 5.78 - ETA: 3:04 - loss: 0.6422 - binary_accuracy: 0.6783 - true_positives: 5.79 - ETA: 3:00 - loss: 0.6410 - binary_accuracy: 0.6804 - true_positives: 5.80 - ETA: 2:56 - loss: 0.6400 - binary_accuracy: 0.6823 - true_positives: 5.80 - ETA: 2:53 - loss: 0.6389 - binary_accuracy: 0.6842 - true_positives: 5.81 - ETA: 2:49 - loss: 0.6376 - binary_accuracy: 0.6861 - true_positives: 5.82 - ETA: 2:47 - loss: 0.6363 - binary_accuracy: 0.6879 - true_positives: 5.82 - ETA: 2:44 - loss: 0.6349 - binary_accuracy: 0.6898 - true_positives: 5.83 - ETA: 2:41 - loss: 0.6336 - binary_accuracy: 0.6915 - true_positives: 5.83 - ETA: 2:38 - loss: 0.6324 - binary_accuracy: 0.6930 - true_positives: 5.84 - ETA: 2:36 - loss: 0.6310 - binary_accuracy: 0.6946 - true_positives: 5.84 - ETA: 2:33 - loss: 0.6297 - binary_accuracy: 0.6962 - true_positives: 5.85 - ETA: 2:31 - loss: 0.6285 - binary_accuracy: 0.6976 - true_positives: 5.85 - ETA: 2:29 - loss: 0.6272 - binary_accuracy: 0.6991 - true_positives: 5.86 - ETA: 2:27 - loss: 0.6260 - binary_accuracy: 0.7004 - true_positives: 5.86 - ETA: 2:25 - loss: 0.6249 - binary_accuracy: 0.7017 - true_positives: 5.86 - ETA: 2:23 - loss: 0.6239 - binary_accuracy: 0.7029 - true_positives: 5.87 - ETA: 2:22 - loss: 0.6230 - binary_accuracy: 0.7039 - true_positives: 5.87 - ETA: 2:20 - loss: 0.6220 - binary_accuracy: 0.7049 - true_positives: 5.87 - ETA: 2:19 - loss: 0.6211 - binary_accuracy: 0.7060 - true_positives: 5.88 - ETA: 2:17 - loss: 0.6203 - binary_accuracy: 0.7069 - true_positives: 5.88 - ETA: 2:16 - loss: 0.6195 - binary_accuracy: 0.7077 - true_positives: 5.88 - ETA: 2:15 - loss: 0.6187 - binary_accuracy: 0.7086 - true_positives: 5.88 - ETA: 2:13 - loss: 0.6179 - binary_accuracy: 0.7094 - true_positives: 5.89 - ETA: 2:12 - loss: 0.6171 - binary_accuracy: 0.7102 - true_positives: 5.89 - ETA: 2:10 - loss: 0.6164 - binary_accuracy: 0.7109 - true_positives: 5.89 - ETA: 2:09 - loss: 0.6157 - binary_accuracy: 0.7117 - true_positives: 5.89 - ETA: 2:09 - loss: 0.6150 - binary_accuracy: 0.7124 - true_positives: 5.90 - ETA: 2:07 - loss: 0.6143 - binary_accuracy: 0.7130 - true_positives: 5.90 - ETA: 2:06 - loss: 0.6137 - binary_accuracy: 0.7137 - true_positi ...
#  216/1000 [=====>........................] - ETA: 1:38 - loss: 0.5929 - binary_accuracy: 0.7323 - true_positives: 5.95 - ETA: 1:38 - loss: 0.5926 - binary_accuracy: 0.7325 - true_positives: 5.95 - ETA: 1:38 - loss: 0.5924 - binary_accuracy: 0.7327 - true_positives: 5.95 - ETA: 1:37 - loss: 0.5922 - binary_accuracy: 0.7328 - true_positives: 5.95 - ETA: 1:37 - loss: 0.5919 - binary_accuracy: 0.7330 - true_positives: 5.95 - ETA: 1:37 - loss: 0.5917 - binary_accuracy: 0.7332 - true_positives: 5.95 - ETA: 1:37 - loss: 0.5915 - binary_accuracy: 0.7334 - true_positives: 5.95 - ETA: 1:37 - loss: 0.5912 - binary_accuracy: 0.7335 - true_positives: 5.95 - ETA: 1:37 - loss: 0.5910 - binary_accuracy: 0.7337 - true_positives: 5.95 - ETA: 1:36 - loss: 0.5908 - binary_accuracy: 0.7338 - true_positives: 5.95 - ETA: 1:36 - loss: 0.5906 - binary_accuracy: 0.7340 - true_positives: 5.95 - ETA: 1:36 - loss: 0.5903 - binary_accuracy: 0.7342 - true_positives: 5.95 - ETA: 1:36 - loss: 0.5901 - binary_accuracy: 0.7343 - true_positives: 5.95 - ETA: 1:36 - loss: 0.5898 - binary_accuracy: 0.7345 - true_positives: 5.95 - ETA: 1:35 - loss: 0.5896 - binary_accuracy: 0.7347 - true_positives: 5.95 - ETA: 1:35 - loss: 0.5893 - binary_accuracy: 0.7349 - true_positives: 5.95 - ETA: 1:35 - loss: 0.5891 - binary_accuracy: 0.7350 - true_positives: 5.96 - ETA: 1:35 - loss: 0.5888 - binary_accuracy: 0.7352 - true_positives: 5.96 - ETA: 1:35 - loss: 0.5886 - binary_accuracy: 0.7354 - true_positives: 5.96 - ETA: 1:34 - loss: 0.5884 - binary_accuracy: 0.7356 - true_positives: 5.96 - ETA: 1:34 - loss: 0.5881 - binary_accuracy: 0.7357 - true_positives: 5.96 - ETA: 1:34 - loss: 0.5879 - binary_accuracy: 0.7359 - true_positives: 5.96 - ETA: 1:34 - loss: 0.5876 - binary_accuracy: 0.7361 - true_positives: 5.96 - ETA: 1:34 - loss: 0.5874 - binary_accuracy: 0.7362 - true_positives: 5.96 - ETA: 1:34 - loss: 0.5872 - binary_accuracy: 0.7364 - true_positives: 5.96 - ETA: 1:34 - loss: 0.5869 - binary_accuracy: 0.7366 - true_positives: 5.96 - ETA: 1:33 - loss: 0.5867 - binary_accuracy: 0.7367 - true_positives: 5.96 - ETA: 1:33 - loss: 0.5864 - binary_accuracy: 0.7369 - true_positives: 5.96 - ETA: 1:33 - loss: 0.5862 - binary_accuracy: 0.7371 - true_positives: 5.96 - ETA: 1:33 - loss: 0.5859 - binary_accuracy: 0.7372 - true_positives: 5.96 - ETA: 1:33 - loss: 0.5857 - binary_accuracy: 0.7374 - true_positives: 5.96 - ETA: 1:32 - loss: 0.5855 - binary_accuracy: 0.7376 - true_positives: 5.96 - ETA: 1:32 - loss: 0.5853 - binary_accuracy: 0.7377 - true_positives: 5.96 - ETA: 1:32 - loss: 0.5850 - binary_accuracy: 0.7379 - true_positives: 5.96 - ETA: 1:32 - loss: 0.5848 - binary_accuracy: 0.7380 - true_positives: 5.96 - ETA: 1:32 - loss: 0.5846 - binary_accuracy: 0.7382 - true_positives: 5.96 - ETA: 1:32 - loss: 0.5843 - binary_accuracy: 0.7384 - true_positives: 5.96 - ETA: 1:32 - loss: 0.5841 - binary_accuracy: 0.7385 - true_positives: 5.96 - ETA: 1:32 - loss: 0.5839 - binary_accuracy: 0.7387 - true_positives: 5.96 - ETA: 1:31 - loss: 0.5836 - binary_accuracy: 0.7388 - true_positives: 5.96 - ETA: 1:31 - loss: 0.5834 - binary_accuracy: 0.7390 - true_positives: 5.96 - ETA: 1:31 - loss: 0.5832 - binary_accuracy: 0.7391 - true_positives: 5.96 - ETA: 1:31 - loss: 0.5830 - binary_accuracy: 0.7393 - true_positives: 5.96 - ETA: 1:31 - loss: 0.5827 - binary_accuracy: 0.7394 - true_positives: 5.96 - ETA: 1:30 - loss: 0.5825 - binary_accuracy: 0.7396 - true_positives: 5.96 - ETA: 1:30 - loss: 0.5823 - binary_accuracy: 0.7397 - true_positives: 5.96 - ETA: 1:30 - loss: 0.5821 - binary_accuracy: 0.7399 - true_positives: 5.96 - ETA: 1:30 - loss: 0.5819 - binary_accuracy: 0.7400 - true_positives: 5.96 - ETA: 1:30 - loss: 0.5817 - binary_accuracy: 0.7401 - true_positives: 5.96 - ETA: 1:30 - loss: 0.5815 - binary_accuracy: 0.7403 - true_positives: 5.96 - ETA: 1:30 - loss: 0.5813 - binary_accuracy: 0.7404 - true_positives: 5.96 - ETA: 1:30 - loss: 0.5811 - binary_accuracy: 0.7405 - true_positives: 5.96 - ETA ...
#  324/1000 [========>.....................] - ETA: 1:23 - loss: 0.5721 - binary_accuracy: 0.7462 - true_positives: 5.97 - ETA: 1:23 - loss: 0.5720 - binary_accuracy: 0.7462 - true_positives: 5.97 - ETA: 1:23 - loss: 0.5719 - binary_accuracy: 0.7463 - true_positives: 5.97 - ETA: 1:23 - loss: 0.5718 - binary_accuracy: 0.7464 - true_positives: 5.97 - ETA: 1:23 - loss: 0.5716 - binary_accuracy: 0.7465 - true_positives: 5.97 - ETA: 1:22 - loss: 0.5715 - binary_accuracy: 0.7466 - true_positives: 5.97 - ETA: 1:22 - loss: 0.5714 - binary_accuracy: 0.7466 - true_positives: 5.97 - ETA: 1:22 - loss: 0.5713 - binary_accuracy: 0.7467 - true_positives: 5.97 - ETA: 1:22 - loss: 0.5711 - binary_accuracy: 0.7468 - true_positives: 5.97 - ETA: 1:22 - loss: 0.5710 - binary_accuracy: 0.7468 - true_positives: 5.97 - ETA: 1:22 - loss: 0.5709 - binary_accuracy: 0.7469 - true_positives: 5.97 - ETA: 1:22 - loss: 0.5708 - binary_accuracy: 0.7470 - true_positives: 5.97 - ETA: 1:22 - loss: 0.5707 - binary_accuracy: 0.7471 - true_positives: 5.97 - ETA: 1:22 - loss: 0.5706 - binary_accuracy: 0.7471 - true_positives: 5.97 - ETA: 1:21 - loss: 0.5704 - binary_accuracy: 0.7472 - true_positives: 5.97 - ETA: 1:21 - loss: 0.5703 - binary_accuracy: 0.7473 - true_positives: 5.97 - ETA: 1:21 - loss: 0.5702 - binary_accuracy: 0.7474 - true_positives: 5.97 - ETA: 1:21 - loss: 0.5701 - binary_accuracy: 0.7474 - true_positives: 5.97 - ETA: 1:21 - loss: 0.5700 - binary_accuracy: 0.7475 - true_positives: 5.97 - ETA: 1:21 - loss: 0.5698 - binary_accuracy: 0.7476 - true_positives: 5.97 - ETA: 1:21 - loss: 0.5697 - binary_accuracy: 0.7476 - true_positives: 5.97 - ETA: 1:21 - loss: 0.5696 - binary_accuracy: 0.7477 - true_positives: 5.97 - ETA: 1:20 - loss: 0.5695 - binary_accuracy: 0.7478 - true_positives: 5.97 - ETA: 1:20 - loss: 0.5694 - binary_accuracy: 0.7478 - true_positives: 5.97 - ETA: 1:20 - loss: 0.5693 - binary_accuracy: 0.7479 - true_positives: 5.97 - ETA: 1:20 - loss: 0.5692 - binary_accuracy: 0.7480 - true_positives: 5.97 - ETA: 1:20 - loss: 0.5690 - binary_accuracy: 0.7480 - true_positives: 5.97 - ETA: 1:20 - loss: 0.5689 - binary_accuracy: 0.7481 - true_positives: 5.97 - ETA: 1:20 - loss: 0.5688 - binary_accuracy: 0.7482 - true_positives: 5.97 - ETA: 1:19 - loss: 0.5687 - binary_accuracy: 0.7482 - true_positives: 5.97 - ETA: 1:19 - loss: 0.5686 - binary_accuracy: 0.7483 - true_positives: 5.97 - ETA: 1:19 - loss: 0.5685 - binary_accuracy: 0.7483 - true_positives: 5.97 - ETA: 1:19 - loss: 0.5684 - binary_accuracy: 0.7484 - true_positives: 5.97 - ETA: 1:19 - loss: 0.5683 - binary_accuracy: 0.7485 - true_positives: 5.98 - ETA: 1:19 - loss: 0.5682 - binary_accuracy: 0.7485 - true_positives: 5.98 - ETA: 1:19 - loss: 0.5681 - binary_accuracy: 0.7486 - true_positives: 5.98 - ETA: 1:19 - loss: 0.5680 - binary_accuracy: 0.7486 - true_positives: 5.98 - ETA: 1:18 - loss: 0.5679 - binary_accuracy: 0.7487 - true_positives: 5.98 - ETA: 1:18 - loss: 0.5678 - binary_accuracy: 0.7487 - true_positives: 5.98 - ETA: 1:18 - loss: 0.5677 - binary_accuracy: 0.7488 - true_positives: 5.98 - ETA: 1:18 - loss: 0.5676 - binary_accuracy: 0.7489 - true_positives: 5.98 - ETA: 1:18 - loss: 0.5675 - binary_accuracy: 0.7489 - true_positives: 5.98 - ETA: 1:18 - loss: 0.5674 - binary_accuracy: 0.7490 - true_positives: 5.98 - ETA: 1:18 - loss: 0.5673 - binary_accuracy: 0.7490 - true_positives: 5.98 - ETA: 1:18 - loss: 0.5672 - binary_accuracy: 0.7491 - true_positives: 5.98 - ETA: 1:17 - loss: 0.5671 - binary_accuracy: 0.7492 - true_positives: 5.98 - ETA: 1:17 - loss: 0.5670 - binary_accuracy: 0.7492 - true_positives: 5.98 - ETA: 1:17 - loss: 0.5669 - binary_accuracy: 0.7493 - true_positives: 5.98 - ETA: 1:17 - loss: 0.5668 - binary_accuracy: 0.7493 - true_positives: 5.98 - ETA: 1:17 - loss: 0.5667 - binary_accuracy: 0.7494 - true_positives: 5.98 - ETA: 1:17 - loss: 0.5666 - binary_accuracy: 0.7494 - true_positives: 5.98 - ETA: 1:17 - loss: 0.5665 - binary_accuracy: 0.7495 - true_positives: 5.98 - ETA ...
#  432/1000 [===========>..................] - ETA: 1:09 - loss: 0.5615 - binary_accuracy: 0.7524 - true_positives: 5.98 - ETA: 1:09 - loss: 0.5614 - binary_accuracy: 0.7524 - true_positives: 5.98 - ETA: 1:09 - loss: 0.5613 - binary_accuracy: 0.7524 - true_positives: 5.98 - ETA: 1:09 - loss: 0.5613 - binary_accuracy: 0.7525 - true_positives: 5.98 - ETA: 1:09 - loss: 0.5612 - binary_accuracy: 0.7525 - true_positives: 5.98 - ETA: 1:09 - loss: 0.5611 - binary_accuracy: 0.7526 - true_positives: 5.98 - ETA: 1:09 - loss: 0.5610 - binary_accuracy: 0.7526 - true_positives: 5.98 - ETA: 1:09 - loss: 0.5610 - binary_accuracy: 0.7527 - true_positives: 5.98 - ETA: 1:08 - loss: 0.5609 - binary_accuracy: 0.7527 - true_positives: 5.98 - ETA: 1:08 - loss: 0.5608 - binary_accuracy: 0.7527 - true_positives: 5.98 - ETA: 1:08 - loss: 0.5607 - binary_accuracy: 0.7528 - true_positives: 5.98 - ETA: 1:08 - loss: 0.5607 - binary_accuracy: 0.7528 - true_positives: 5.98 - ETA: 1:08 - loss: 0.5606 - binary_accuracy: 0.7529 - true_positives: 5.98 - ETA: 1:08 - loss: 0.5605 - binary_accuracy: 0.7529 - true_positives: 5.98 - ETA: 1:08 - loss: 0.5604 - binary_accuracy: 0.7530 - true_positives: 5.98 - ETA: 1:08 - loss: 0.5603 - binary_accuracy: 0.7530 - true_positives: 5.98 - ETA: 1:07 - loss: 0.5603 - binary_accuracy: 0.7530 - true_positives: 5.98 - ETA: 1:07 - loss: 0.5602 - binary_accuracy: 0.7531 - true_positives: 5.98 - ETA: 1:07 - loss: 0.5601 - binary_accuracy: 0.7531 - true_positives: 5.98 - ETA: 1:07 - loss: 0.5600 - binary_accuracy: 0.7532 - true_positives: 5.98 - ETA: 1:07 - loss: 0.5600 - binary_accuracy: 0.7532 - true_positives: 5.98 - ETA: 1:07 - loss: 0.5599 - binary_accuracy: 0.7533 - true_positives: 5.98 - ETA: 1:07 - loss: 0.5598 - binary_accuracy: 0.7533 - true_positives: 5.98 - ETA: 1:07 - loss: 0.5598 - binary_accuracy: 0.7533 - true_positives: 5.98 - ETA: 1:06 - loss: 0.5597 - binary_accuracy: 0.7534 - true_positives: 5.98 - ETA: 1:06 - loss: 0.5596 - binary_accuracy: 0.7534 - true_positives: 5.98 - ETA: 1:06 - loss: 0.5595 - binary_accuracy: 0.7535 - true_positives: 5.98 - ETA: 1:06 - loss: 0.5595 - binary_accuracy: 0.7535 - true_positives: 5.98 - ETA: 1:06 - loss: 0.5594 - binary_accuracy: 0.7535 - true_positives: 5.98 - ETA: 1:06 - loss: 0.5593 - binary_accuracy: 0.7536 - true_positives: 5.98 - ETA: 1:06 - loss: 0.5592 - binary_accuracy: 0.7536 - true_positives: 5.98 - ETA: 1:06 - loss: 0.5592 - binary_accuracy: 0.7537 - true_positives: 5.98 - ETA: 1:06 - loss: 0.5591 - binary_accuracy: 0.7537 - true_positives: 5.98 - ETA: 1:06 - loss: 0.5590 - binary_accuracy: 0.7537 - true_positives: 5.98 - ETA: 1:05 - loss: 0.5590 - binary_accuracy: 0.7538 - true_positives: 5.98 - ETA: 1:05 - loss: 0.5589 - binary_accuracy: 0.7538 - true_positives: 5.98 - ETA: 1:05 - loss: 0.5588 - binary_accuracy: 0.7539 - true_positives: 5.98 - ETA: 1:05 - loss: 0.5587 - binary_accuracy: 0.7539 - true_positives: 5.98 - ETA: 1:05 - loss: 0.5587 - binary_accuracy: 0.7539 - true_positives: 5.98 - ETA: 1:05 - loss: 0.5586 - binary_accuracy: 0.7540 - true_positives: 5.98 - ETA: 1:05 - loss: 0.5585 - binary_accuracy: 0.7540 - true_positives: 5.98 - ETA: 1:05 - loss: 0.5585 - binary_accuracy: 0.7541 - true_positives: 5.98 - ETA: 1:05 - loss: 0.5584 - binary_accuracy: 0.7541 - true_positives: 5.98 - ETA: 1:04 - loss: 0.5583 - binary_accuracy: 0.7541 - true_positives: 5.98 - ETA: 1:04 - loss: 0.5583 - binary_accuracy: 0.7542 - true_positives: 5.98 - ETA: 1:04 - loss: 0.5582 - binary_accuracy: 0.7542 - true_positives: 5.98 - ETA: 1:04 - loss: 0.5581 - binary_accuracy: 0.7542 - true_positives: 5.98 - ETA: 1:04 - loss: 0.5581 - binary_accuracy: 0.7543 - true_positives: 5.98 - ETA: 1:04 - loss: 0.5580 - binary_accuracy: 0.7543 - true_positives: 5.98 - ETA: 1:04 - loss: 0.5580 - binary_accuracy: 0.7543 - true_positives: 5.98 - ETA: 1:04 - loss: 0.5579 - binary_accuracy: 0.7544 - true_positives: 5.98 - ETA: 1:04 - loss: 0.5578 - binary_accuracy: 0.7544 - true_positives: 5.98 - ETA ...
#  540/1000 [===============>..............] - ETA: 57s - loss: 0.5548 - binary_accuracy: 0.7558 - true_positives: 5.988 - ETA: 57s - loss: 0.5548 - binary_accuracy: 0.7558 - true_positives: 5.988 - ETA: 57s - loss: 0.5547 - binary_accuracy: 0.7558 - true_positives: 5.988 - ETA: 57s - loss: 0.5547 - binary_accuracy: 0.7559 - true_positives: 5.988 - ETA: 57s - loss: 0.5546 - binary_accuracy: 0.7559 - true_positives: 5.988 - ETA: 57s - loss: 0.5546 - binary_accuracy: 0.7559 - true_positives: 5.988 - ETA: 56s - loss: 0.5545 - binary_accuracy: 0.7559 - true_positives: 5.988 - ETA: 56s - loss: 0.5545 - binary_accuracy: 0.7560 - true_positives: 5.988 - ETA: 56s - loss: 0.5544 - binary_accuracy: 0.7560 - true_positives: 5.988 - ETA: 56s - loss: 0.5544 - binary_accuracy: 0.7560 - true_positives: 5.988 - ETA: 56s - loss: 0.5543 - binary_accuracy: 0.7560 - true_positives: 5.988 - ETA: 56s - loss: 0.5543 - binary_accuracy: 0.7560 - true_positives: 5.988 - ETA: 56s - loss: 0.5542 - binary_accuracy: 0.7561 - true_positives: 5.988 - ETA: 56s - loss: 0.5542 - binary_accuracy: 0.7561 - true_positives: 5.988 - ETA: 56s - loss: 0.5541 - binary_accuracy: 0.7561 - true_positives: 5.988 - ETA: 56s - loss: 0.5541 - binary_accuracy: 0.7561 - true_positives: 5.988 - ETA: 55s - loss: 0.5540 - binary_accuracy: 0.7562 - true_positives: 5.988 - ETA: 55s - loss: 0.5540 - binary_accuracy: 0.7562 - true_positives: 5.988 - ETA: 55s - loss: 0.5539 - binary_accuracy: 0.7562 - true_positives: 5.988 - ETA: 55s - loss: 0.5539 - binary_accuracy: 0.7562 - true_positives: 5.988 - ETA: 55s - loss: 0.5538 - binary_accuracy: 0.7562 - true_positives: 5.989 - ETA: 55s - loss: 0.5538 - binary_accuracy: 0.7563 - true_positives: 5.989 - ETA: 55s - loss: 0.5537 - binary_accuracy: 0.7563 - true_positives: 5.989 - ETA: 55s - loss: 0.5537 - binary_accuracy: 0.7563 - true_positives: 5.989 - ETA: 55s - loss: 0.5537 - binary_accuracy: 0.7563 - true_positives: 5.989 - ETA: 54s - loss: 0.5536 - binary_accuracy: 0.7563 - true_positives: 5.989 - ETA: 54s - loss: 0.5536 - binary_accuracy: 0.7564 - true_positives: 5.989 - ETA: 54s - loss: 0.5535 - binary_accuracy: 0.7564 - true_positives: 5.989 - ETA: 54s - loss: 0.5535 - binary_accuracy: 0.7564 - true_positives: 5.989 - ETA: 54s - loss: 0.5534 - binary_accuracy: 0.7564 - true_positives: 5.989 - ETA: 54s - loss: 0.5534 - binary_accuracy: 0.7564 - true_positives: 5.989 - ETA: 54s - loss: 0.5533 - binary_accuracy: 0.7565 - true_positives: 5.989 - ETA: 54s - loss: 0.5533 - binary_accuracy: 0.7565 - true_positives: 5.989 - ETA: 54s - loss: 0.5532 - binary_accuracy: 0.7565 - true_positives: 5.989 - ETA: 54s - loss: 0.5532 - binary_accuracy: 0.7565 - true_positives: 5.989 - ETA: 54s - loss: 0.5532 - binary_accuracy: 0.7565 - true_positives: 5.989 - ETA: 53s - loss: 0.5531 - binary_accuracy: 0.7566 - true_positives: 5.989 - ETA: 53s - loss: 0.5531 - binary_accuracy: 0.7566 - true_positives: 5.989 - ETA: 53s - loss: 0.5530 - binary_accuracy: 0.7566 - true_positives: 5.989 - ETA: 53s - loss: 0.5530 - binary_accuracy: 0.7566 - true_positives: 5.989 - ETA: 53s - loss: 0.5529 - binary_accuracy: 0.7566 - true_positives: 5.989 - ETA: 53s - loss: 0.5529 - binary_accuracy: 0.7567 - true_positives: 5.989 - ETA: 53s - loss: 0.5528 - binary_accuracy: 0.7567 - true_positives: 5.989 - ETA: 53s - loss: 0.5528 - binary_accuracy: 0.7567 - true_positives: 5.989 - ETA: 53s - loss: 0.5527 - binary_accuracy: 0.7567 - true_positives: 5.989 - ETA: 53s - loss: 0.5527 - binary_accuracy: 0.7567 - true_positives: 5.989 - ETA: 53s - loss: 0.5527 - binary_accuracy: 0.7568 - true_positives: 5.989 - ETA: 52s - loss: 0.5526 - binary_accuracy: 0.7568 - true_positives: 5.989 - ETA: 52s - loss: 0.5526 - binary_accuracy: 0.7568 - true_positives: 5.989 - ETA: 52s - loss: 0.5525 - binary_accuracy: 0.7568 - true_positives: 5.989 - ETA: 52s - loss: 0.5525 - binary_accuracy: 0.7568 - true_positives: 5.989 - ETA: 52s - loss: 0.5524 - binary_accuracy: 0.7569 - true_positives: 5.989 - ETA ...
#  648/1000 [==================>...........] - ETA: 46s - loss: 0.5503 - binary_accuracy: 0.7577 - true_positives: 6.220 - ETA: 46s - loss: 0.5503 - binary_accuracy: 0.7577 - true_positives: 6.230 - ETA: 46s - loss: 0.5502 - binary_accuracy: 0.7578 - true_positives: 6.241 - ETA: 46s - loss: 0.5502 - binary_accuracy: 0.7578 - true_positives: 6.251 - ETA: 46s - loss: 0.5502 - binary_accuracy: 0.7578 - true_positives: 6.262 - ETA: 46s - loss: 0.5501 - binary_accuracy: 0.7578 - true_positives: 6.272 - ETA: 46s - loss: 0.5501 - binary_accuracy: 0.7578 - true_positives: 6.283 - ETA: 46s - loss: 0.5501 - binary_accuracy: 0.7578 - true_positives: 6.293 - ETA: 46s - loss: 0.5500 - binary_accuracy: 0.7578 - true_positives: 6.304 - ETA: 45s - loss: 0.5500 - binary_accuracy: 0.7578 - true_positives: 6.314 - ETA: 45s - loss: 0.5500 - binary_accuracy: 0.7578 - true_positives: 6.324 - ETA: 45s - loss: 0.5499 - binary_accuracy: 0.7579 - true_positives: 6.335 - ETA: 45s - loss: 0.5499 - binary_accuracy: 0.7579 - true_positives: 6.345 - ETA: 45s - loss: 0.5499 - binary_accuracy: 0.7579 - true_positives: 6.357 - ETA: 45s - loss: 0.5498 - binary_accuracy: 0.7579 - true_positives: 6.369 - ETA: 45s - loss: 0.5498 - binary_accuracy: 0.7579 - true_positives: 6.381 - ETA: 45s - loss: 0.5498 - binary_accuracy: 0.7579 - true_positives: 6.393 - ETA: 45s - loss: 0.5497 - binary_accuracy: 0.7579 - true_positives: 6.405 - ETA: 44s - loss: 0.5497 - binary_accuracy: 0.7579 - true_positives: 6.416 - ETA: 44s - loss: 0.5497 - binary_accuracy: 0.7579 - true_positives: 6.428 - ETA: 44s - loss: 0.5496 - binary_accuracy: 0.7580 - true_positives: 6.440 - ETA: 44s - loss: 0.5496 - binary_accuracy: 0.7580 - true_positives: 6.452 - ETA: 44s - loss: 0.5496 - binary_accuracy: 0.7580 - true_positives: 6.463 - ETA: 44s - loss: 0.5496 - binary_accuracy: 0.7580 - true_positives: 6.475 - ETA: 44s - loss: 0.5495 - binary_accuracy: 0.7580 - true_positives: 6.486 - ETA: 44s - loss: 0.5495 - binary_accuracy: 0.7580 - true_positives: 6.498 - ETA: 44s - loss: 0.5495 - binary_accuracy: 0.7580 - true_positives: 6.509 - ETA: 43s - loss: 0.5494 - binary_accuracy: 0.7580 - true_positives: 6.521 - ETA: 43s - loss: 0.5494 - binary_accuracy: 0.7580 - true_positives: 6.532 - ETA: 43s - loss: 0.5494 - binary_accuracy: 0.7581 - true_positives: 6.543 - ETA: 43s - loss: 0.5493 - binary_accuracy: 0.7581 - true_positives: 6.555 - ETA: 43s - loss: 0.5493 - binary_accuracy: 0.7581 - true_positives: 6.566 - ETA: 43s - loss: 0.5493 - binary_accuracy: 0.7581 - true_positives: 6.577 - ETA: 43s - loss: 0.5493 - binary_accuracy: 0.7581 - true_positives: 6.588 - ETA: 43s - loss: 0.5492 - binary_accuracy: 0.7581 - true_positives: 6.600 - ETA: 43s - loss: 0.5492 - binary_accuracy: 0.7581 - true_positives: 6.611 - ETA: 43s - loss: 0.5492 - binary_accuracy: 0.7581 - true_positives: 6.622 - ETA: 42s - loss: 0.5491 - binary_accuracy: 0.7581 - true_positives: 6.633 - ETA: 42s - loss: 0.5491 - binary_accuracy: 0.7581 - true_positives: 6.644 - ETA: 42s - loss: 0.5491 - binary_accuracy: 0.7582 - true_positives: 6.655 - ETA: 42s - loss: 0.5490 - binary_accuracy: 0.7582 - true_positives: 6.666 - ETA: 42s - loss: 0.5490 - binary_accuracy: 0.7582 - true_positives: 6.677 - ETA: 42s - loss: 0.5490 - binary_accuracy: 0.7582 - true_positives: 6.687 - ETA: 42s - loss: 0.5490 - binary_accuracy: 0.7582 - true_positives: 6.698 - ETA: 42s - loss: 0.5489 - binary_accuracy: 0.7582 - true_positives: 6.709 - ETA: 42s - loss: 0.5489 - binary_accuracy: 0.7582 - true_positives: 6.720 - ETA: 42s - loss: 0.5489 - binary_accuracy: 0.7582 - true_positives: 6.730 - ETA: 41s - loss: 0.5488 - binary_accuracy: 0.7582 - true_positives: 6.741 - ETA: 41s - loss: 0.5488 - binary_accuracy: 0.7583 - true_positives: 6.752 - ETA: 41s - loss: 0.5488 - binary_accuracy: 0.7583 - true_positives: 6.762 - ETA: 41s - loss: 0.5488 - binary_accuracy: 0.7583 - true_positives: 6.773 - ETA: 41s - loss: 0.5487 - binary_accuracy: 0.7583 - true_positives: 6.783 - ETA ...
#  756/1000 [=====================>........] - ETA: 35s - loss: 0.5473 - binary_accuracy: 0.7587 - true_positives: 7.335 - ETA: 35s - loss: 0.5473 - binary_accuracy: 0.7587 - true_positives: 7.346 - ETA: 35s - loss: 0.5473 - binary_accuracy: 0.7587 - true_positives: 7.356 - ETA: 35s - loss: 0.5473 - binary_accuracy: 0.7587 - true_positives: 7.366 - ETA: 35s - loss: 0.5473 - binary_accuracy: 0.7587 - true_positives: 7.376 - ETA: 34s - loss: 0.5472 - binary_accuracy: 0.7587 - true_positives: 7.386 - ETA: 34s - loss: 0.5472 - binary_accuracy: 0.7587 - true_positives: 7.396 - ETA: 34s - loss: 0.5472 - binary_accuracy: 0.7587 - true_positives: 7.407 - ETA: 34s - loss: 0.5472 - binary_accuracy: 0.7587 - true_positives: 7.417 - ETA: 34s - loss: 0.5472 - binary_accuracy: 0.7587 - true_positives: 7.427 - ETA: 34s - loss: 0.5471 - binary_accuracy: 0.7587 - true_positives: 7.437 - ETA: 34s - loss: 0.5471 - binary_accuracy: 0.7587 - true_positives: 7.447 - ETA: 34s - loss: 0.5471 - binary_accuracy: 0.7587 - true_positives: 7.456 - ETA: 34s - loss: 0.5471 - binary_accuracy: 0.7587 - true_positives: 7.466 - ETA: 34s - loss: 0.5471 - binary_accuracy: 0.7587 - true_positives: 7.476 - ETA: 33s - loss: 0.5470 - binary_accuracy: 0.7587 - true_positives: 7.486 - ETA: 33s - loss: 0.5470 - binary_accuracy: 0.7587 - true_positives: 7.496 - ETA: 33s - loss: 0.5470 - binary_accuracy: 0.7587 - true_positives: 7.506 - ETA: 33s - loss: 0.5470 - binary_accuracy: 0.7587 - true_positives: 7.515 - ETA: 33s - loss: 0.5469 - binary_accuracy: 0.7587 - true_positives: 7.525 - ETA: 33s - loss: 0.5469 - binary_accuracy: 0.7587 - true_positives: 7.535 - ETA: 33s - loss: 0.5469 - binary_accuracy: 0.7587 - true_positives: 7.544 - ETA: 33s - loss: 0.5469 - binary_accuracy: 0.7587 - true_positives: 7.555 - ETA: 33s - loss: 0.5469 - binary_accuracy: 0.7588 - true_positives: 7.567 - ETA: 33s - loss: 0.5468 - binary_accuracy: 0.7588 - true_positives: 7.578 - ETA: 32s - loss: 0.5468 - binary_accuracy: 0.7588 - true_positives: 7.589 - ETA: 32s - loss: 0.5468 - binary_accuracy: 0.7588 - true_positives: 7.600 - ETA: 32s - loss: 0.5468 - binary_accuracy: 0.7588 - true_positives: 7.610 - ETA: 32s - loss: 0.5468 - binary_accuracy: 0.7588 - true_positives: 7.621 - ETA: 32s - loss: 0.5467 - binary_accuracy: 0.7588 - true_positives: 7.632 - ETA: 32s - loss: 0.5467 - binary_accuracy: 0.7588 - true_positives: 7.643 - ETA: 32s - loss: 0.5467 - binary_accuracy: 0.7588 - true_positives: 7.654 - ETA: 32s - loss: 0.5467 - binary_accuracy: 0.7588 - true_positives: 7.665 - ETA: 32s - loss: 0.5467 - binary_accuracy: 0.7588 - true_positives: 7.676 - ETA: 32s - loss: 0.5466 - binary_accuracy: 0.7588 - true_positives: 7.688 - ETA: 31s - loss: 0.5466 - binary_accuracy: 0.7588 - true_positives: 7.700 - ETA: 31s - loss: 0.5466 - binary_accuracy: 0.7588 - true_positives: 7.712 - ETA: 31s - loss: 0.5466 - binary_accuracy: 0.7588 - true_positives: 7.724 - ETA: 31s - loss: 0.5466 - binary_accuracy: 0.7588 - true_positives: 7.736 - ETA: 31s - loss: 0.5465 - binary_accuracy: 0.7588 - true_positives: 7.748 - ETA: 31s - loss: 0.5465 - binary_accuracy: 0.7588 - true_positives: 7.760 - ETA: 31s - loss: 0.5465 - binary_accuracy: 0.7588 - true_positives: 7.772 - ETA: 31s - loss: 0.5465 - binary_accuracy: 0.7589 - true_positives: 7.784 - ETA: 31s - loss: 0.5464 - binary_accuracy: 0.7589 - true_positives: 7.796 - ETA: 30s - loss: 0.5464 - binary_accuracy: 0.7589 - true_positives: 7.808 - ETA: 30s - loss: 0.5464 - binary_accuracy: 0.7589 - true_positives: 7.819 - ETA: 30s - loss: 0.5464 - binary_accuracy: 0.7589 - true_positives: 7.831 - ETA: 30s - loss: 0.5464 - binary_accuracy: 0.7589 - true_positives: 7.843 - ETA: 30s - loss: 0.5463 - binary_accuracy: 0.7589 - true_positives: 7.856 - ETA: 30s - loss: 0.5463 - binary_accuracy: 0.7589 - true_positives: 7.869 - ETA: 30s - loss: 0.5463 - binary_accuracy: 0.7589 - true_positives: 7.882 - ETA: 30s - loss: 0.5463 - binary_accuracy: 0.7589 - true_positives: 7.895 - ETA ...
#  864/1000 [========================>.....] - ETA: 24s - loss: 0.5451 - binary_accuracy: 0.7592 - true_positives: 8.581 - ETA: 24s - loss: 0.5451 - binary_accuracy: 0.7592 - true_positives: 8.592 - ETA: 24s - loss: 0.5451 - binary_accuracy: 0.7592 - true_positives: 8.603 - ETA: 24s - loss: 0.5451 - binary_accuracy: 0.7592 - true_positives: 8.614 - ETA: 24s - loss: 0.5450 - binary_accuracy: 0.7592 - true_positives: 8.625 - ETA: 23s - loss: 0.5450 - binary_accuracy: 0.7592 - true_positives: 8.636 - ETA: 23s - loss: 0.5450 - binary_accuracy: 0.7592 - true_positives: 8.647 - ETA: 23s - loss: 0.5450 - binary_accuracy: 0.7592 - true_positives: 8.658 - ETA: 23s - loss: 0.5450 - binary_accuracy: 0.7593 - true_positives: 8.669 - ETA: 23s - loss: 0.5449 - binary_accuracy: 0.7593 - true_positives: 8.680 - ETA: 23s - loss: 0.5449 - binary_accuracy: 0.7593 - true_positives: 8.691 - ETA: 23s - loss: 0.5449 - binary_accuracy: 0.7593 - true_positives: 8.701 - ETA: 23s - loss: 0.5449 - binary_accuracy: 0.7593 - true_positives: 8.712 - ETA: 23s - loss: 0.5449 - binary_accuracy: 0.7593 - true_positives: 8.723 - ETA: 22s - loss: 0.5449 - binary_accuracy: 0.7593 - true_positives: 8.734 - ETA: 22s - loss: 0.5448 - binary_accuracy: 0.7593 - true_positives: 8.744 - ETA: 22s - loss: 0.5448 - binary_accuracy: 0.7593 - true_positives: 8.755 - ETA: 22s - loss: 0.5448 - binary_accuracy: 0.7593 - true_positives: 8.766 - ETA: 22s - loss: 0.5448 - binary_accuracy: 0.7593 - true_positives: 8.776 - ETA: 22s - loss: 0.5448 - binary_accuracy: 0.7593 - true_positives: 8.787 - ETA: 22s - loss: 0.5447 - binary_accuracy: 0.7593 - true_positives: 8.797 - ETA: 22s - loss: 0.5447 - binary_accuracy: 0.7593 - true_positives: 8.808 - ETA: 22s - loss: 0.5447 - binary_accuracy: 0.7593 - true_positives: 8.819 - ETA: 22s - loss: 0.5447 - binary_accuracy: 0.7593 - true_positives: 8.829 - ETA: 21s - loss: 0.5447 - binary_accuracy: 0.7593 - true_positives: 8.839 - ETA: 21s - loss: 0.5446 - binary_accuracy: 0.7593 - true_positives: 8.850 - ETA: 21s - loss: 0.5446 - binary_accuracy: 0.7593 - true_positives: 8.860 - ETA: 21s - loss: 0.5446 - binary_accuracy: 0.7593 - true_positives: 8.872 - ETA: 21s - loss: 0.5446 - binary_accuracy: 0.7593 - true_positives: 8.884 - ETA: 21s - loss: 0.5446 - binary_accuracy: 0.7594 - true_positives: 8.895 - ETA: 21s - loss: 0.5446 - binary_accuracy: 0.7594 - true_positives: 8.907 - ETA: 21s - loss: 0.5445 - binary_accuracy: 0.7594 - true_positives: 8.918 - ETA: 21s - loss: 0.5445 - binary_accuracy: 0.7594 - true_positives: 8.930 - ETA: 21s - loss: 0.5445 - binary_accuracy: 0.7594 - true_positives: 8.943 - ETA: 20s - loss: 0.5445 - binary_accuracy: 0.7594 - true_positives: 8.955 - ETA: 20s - loss: 0.5445 - binary_accuracy: 0.7594 - true_positives: 8.968 - ETA: 20s - loss: 0.5444 - binary_accuracy: 0.7594 - true_positives: 8.981 - ETA: 20s - loss: 0.5444 - binary_accuracy: 0.7594 - true_positives: 8.996 - ETA: 20s - loss: 0.5444 - binary_accuracy: 0.7594 - true_positives: 9.011 - ETA: 20s - loss: 0.5444 - binary_accuracy: 0.7594 - true_positives: 9.026 - ETA: 20s - loss: 0.5444 - binary_accuracy: 0.7594 - true_positives: 9.041 - ETA: 20s - loss: 0.5444 - binary_accuracy: 0.7594 - true_positives: 9.056 - ETA: 20s - loss: 0.5443 - binary_accuracy: 0.7594 - true_positives: 9.071 - ETA: 20s - loss: 0.5443 - binary_accuracy: 0.7594 - true_positives: 9.086 - ETA: 19s - loss: 0.5443 - binary_accuracy: 0.7594 - true_positives: 9.101 - ETA: 19s - loss: 0.5443 - binary_accuracy: 0.7594 - true_positives: 9.116 - ETA: 19s - loss: 0.5443 - binary_accuracy: 0.7594 - true_positives: 9.130 - ETA: 19s - loss: 0.5443 - binary_accuracy: 0.7594 - true_positives: 9.145 - ETA: 19s - loss: 0.5442 - binary_accuracy: 0.7594 - true_positives: 9.160 - ETA: 19s - loss: 0.5442 - binary_accuracy: 0.7594 - true_positives: 9.174 - ETA: 19s - loss: 0.5442 - binary_accuracy: 0.7594 - true_positives: 9.189 - ETA: 19s - loss: 0.5442 - binary_accuracy: 0.7594 - true_positives: 9.204 - ETA ...
#  972/1000 [============================>.] - ETA: 13s - loss: 0.5432 - binary_accuracy: 0.7597 - true_positives: 9.981 - ETA: 13s - loss: 0.5432 - binary_accuracy: 0.7597 - true_positives: 9.994 - ETA: 13s - loss: 0.5432 - binary_accuracy: 0.7597 - true_positives: 10.00 - ETA: 13s - loss: 0.5431 - binary_accuracy: 0.7597 - true_positives: 10.01 - ETA: 13s - loss: 0.5431 - binary_accuracy: 0.7597 - true_positives: 10.03 - ETA: 12s - loss: 0.5431 - binary_accuracy: 0.7597 - true_positives: 10.04 - ETA: 12s - loss: 0.5431 - binary_accuracy: 0.7597 - true_positives: 10.05 - ETA: 12s - loss: 0.5431 - binary_accuracy: 0.7597 - true_positives: 10.07 - ETA: 12s - loss: 0.5431 - binary_accuracy: 0.7597 - true_positives: 10.08 - ETA: 12s - loss: 0.5430 - binary_accuracy: 0.7597 - true_positives: 10.09 - ETA: 12s - loss: 0.5430 - binary_accuracy: 0.7597 - true_positives: 10.10 - ETA: 12s - loss: 0.5430 - binary_accuracy: 0.7597 - true_positives: 10.12 - ETA: 12s - loss: 0.5430 - binary_accuracy: 0.7597 - true_positives: 10.13 - ETA: 12s - loss: 0.5430 - binary_accuracy: 0.7597 - true_positives: 10.14 - ETA: 12s - loss: 0.5430 - binary_accuracy: 0.7597 - true_positives: 10.16 - ETA: 11s - loss: 0.5429 - binary_accuracy: 0.7597 - true_positives: 10.17 - ETA: 11s - loss: 0.5429 - binary_accuracy: 0.7597 - true_positives: 10.18 - ETA: 11s - loss: 0.5429 - binary_accuracy: 0.7597 - true_positives: 10.20 - ETA: 11s - loss: 0.5429 - binary_accuracy: 0.7597 - true_positives: 10.21 - ETA: 11s - loss: 0.5429 - binary_accuracy: 0.7597 - true_positives: 10.22 - ETA: 11s - loss: 0.5429 - binary_accuracy: 0.7597 - true_positives: 10.24 - ETA: 11s - loss: 0.5429 - binary_accuracy: 0.7597 - true_positives: 10.25 - ETA: 11s - loss: 0.5428 - binary_accuracy: 0.7598 - true_positives: 10.26 - ETA: 11s - loss: 0.5428 - binary_accuracy: 0.7598 - true_positives: 10.28 - ETA: 11s - loss: 0.5428 - binary_accuracy: 0.7598 - true_positives: 10.29 - ETA: 10s - loss: 0.5428 - binary_accuracy: 0.7598 - true_positives: 10.30 - ETA: 10s - loss: 0.5428 - binary_accuracy: 0.7598 - true_positives: 10.32 - ETA: 10s - loss: 0.5428 - binary_accuracy: 0.7598 - true_positives: 10.33 - ETA: 10s - loss: 0.5427 - binary_accuracy: 0.7598 - true_positives: 10.34 - ETA: 10s - loss: 0.5427 - binary_accuracy: 0.7598 - true_positives: 10.36 - ETA: 10s - loss: 0.5427 - binary_accuracy: 0.7598 - true_positives: 10.37 - ETA: 10s - loss: 0.5427 - binary_accuracy: 0.7598 - true_positives: 10.38 - ETA: 10s - loss: 0.5427 - binary_accuracy: 0.7598 - true_positives: 10.40 - ETA: 10s - loss: 0.5427 - binary_accuracy: 0.7598 - true_positives: 10.41 - ETA: 10s - loss: 0.5426 - binary_accuracy: 0.7598 - true_positives: 10.42 - ETA: 10s - loss: 0.5426 - binary_accuracy: 0.7598 - true_positives: 10.43 - ETA: 9s - loss: 0.5426 - binary_accuracy: 0.7598 - true_positives: 10.4517 - ETA: 9s - loss: 0.5426 - binary_accuracy: 0.7598 - true_positives: 10.464 - ETA: 9s - loss: 0.5426 - binary_accuracy: 0.7598 - true_positives: 10.477 - ETA: 9s - loss: 0.5426 - binary_accuracy: 0.7598 - true_positives: 10.490 - ETA: 9s - loss: 0.5425 - binary_accuracy: 0.7598 - true_positives: 10.502 - ETA: 9s - loss: 0.5425 - binary_accuracy: 0.7598 - true_positives: 10.515 - ETA: 9s - loss: 0.5425 - binary_accuracy: 0.7598 - true_positives: 10.528 - ETA: 9s - loss: 0.5425 - binary_accuracy: 0.7598 - true_positives: 10.540 - ETA: 9s - loss: 0.5425 - binary_accuracy: 0.7598 - true_positives: 10.553 - ETA: 9s - loss: 0.5425 - binary_accuracy: 0.7599 - true_positives: 10.565 - ETA: 8s - loss: 0.5424 - binary_accuracy: 0.7599 - true_positives: 10.578 - ETA: 8s - loss: 0.5424 - binary_accuracy: 0.7599 - true_positives: 10.591 - ETA: 8s - loss: 0.5424 - binary_accuracy: 0.7599 - true_positives: 10.603 - ETA: 8s - loss: 0.5424 - binary_accuracy: 0.7599 - true_positives: 10.616 - ETA: 8s - loss: 0.5424 - binary_accuracy: 0.7599 - true_positives: 10.628 - ETA: 8s - loss: 0.5424 - binary_accuracy: 0.7599 - true_positives: 10.640 - ET ...
# 1000/1000 [==============================] - ETA: 2s - loss: 0.5414 - binary_accuracy: 0.7602 - true_positives: 11.326 - ETA: 2s - loss: 0.5414 - binary_accuracy: 0.7602 - true_positives: 11.338 - ETA: 2s - loss: 0.5414 - binary_accuracy: 0.7602 - true_positives: 11.350 - ETA: 2s - loss: 0.5413 - binary_accuracy: 0.7602 - true_positives: 11.362 - ETA: 2s - loss: 0.5413 - binary_accuracy: 0.7602 - true_positives: 11.374 - ETA: 2s - loss: 0.5413 - binary_accuracy: 0.7602 - true_positives: 11.386 - ETA: 2s - loss: 0.5413 - binary_accuracy: 0.7602 - true_positives: 11.398 - ETA: 2s - loss: 0.5413 - binary_accuracy: 0.7602 - true_positives: 11.410 - ETA: 1s - loss: 0.5413 - binary_accuracy: 0.7602 - true_positives: 11.422 - ETA: 1s - loss: 0.5412 - binary_accuracy: 0.7602 - true_positives: 11.433 - ETA: 1s - loss: 0.5412 - binary_accuracy: 0.7602 - true_positives: 11.445 - ETA: 1s - loss: 0.5412 - binary_accuracy: 0.7602 - true_positives: 11.457 - ETA: 1s - loss: 0.5412 - binary_accuracy: 0.7603 - true_positives: 11.469 - ETA: 1s - loss: 0.5412 - binary_accuracy: 0.7603 - true_positives: 11.480 - ETA: 1s - loss: 0.5412 - binary_accuracy: 0.7603 - true_positives: 11.492 - ETA: 1s - loss: 0.5411 - binary_accuracy: 0.7603 - true_positives: 11.504 - ETA: 1s - loss: 0.5411 - binary_accuracy: 0.7603 - true_positives: 11.515 - ETA: 1s - loss: 0.5411 - binary_accuracy: 0.7603 - true_positives: 11.527 - ETA: 0s - loss: 0.5411 - binary_accuracy: 0.7603 - true_positives: 11.538 - ETA: 0s - loss: 0.5411 - binary_accuracy: 0.7603 - true_positives: 11.550 - ETA: 0s - loss: 0.5411 - binary_accuracy: 0.7603 - true_positives: 11.561 - ETA: 0s - loss: 0.5410 - binary_accuracy: 0.7603 - true_positives: 11.573 - ETA: 0s - loss: 0.5410 - binary_accuracy: 0.7603 - true_positives: 11.584 - ETA: 0s - loss: 0.5410 - binary_accuracy: 0.7603 - true_positives: 11.596 - ETA: 0s - loss: 0.5410 - binary_accuracy: 0.7603 - true_positives: 11.607 - ETA: 0s - loss: 0.5410 - binary_accuracy: 0.7603 - true_positives: 11.619 - ETA: 0s - loss: 0.5410 - binary_accuracy: 0.7603 - true_positives: 11.630 - ETA: 0s - loss: 0.5409 - binary_accuracy: 0.7603 - true_positives: 11.643 - 134s 117ms/step - loss: 0.5409 - binary_accuracy: 0.7603 - true_positives: 11.6553 - val_loss: 0.5244 - val_binary_accuracy: 0.7669 - val_true_positives: 9.0000
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Assets written to: /home/jagan-ds/Documents/Tensorflow-Extended-tutorial/temp_/Trainer/model/22/serving_model_dir/assets
# INFO:tensorflow:Assets written to: /home/jagan-ds/Documents/Tensorflow-Extended-tutorial/temp_/Trainer/model/22/serving_model_dir/assets
# ExecutionResult(
#     component_id: Trainer
#     execution_id: 22
#     outputs:
#         model: Channel(
#             type_name: Model
#             artifacts: [Artifact(artifact: id: 35
#         type_id: 17
#         uri: "/home/jagan-ds/Documents/Tensorflow-Extended-tutorial/temp_/Trainer/model/22"
#         custom_properties {
#           key: "name"
#           value {
#             string_value: "model"
#           }
#         }
#         custom_properties {
#           key: "producer_component"
#           value {
#             string_value: "Trainer"
#           }
#         }
#         custom_properties {
#           key: "state"
#           value {
#             string_value: "published"
#           }
#         }
#         state: LIVE
#         , artifact_type: id: 17
#         name: "Model"
#         )]
#             additional_properties: {}
#             additional_custom_properties: {}
#         )
#         model_run: Channel(
#             type_name: ModelRun
#             artifacts: [Artifact(artifact: id: 36
#         type_id: 18
#         uri: "/home/jagan-ds/Documents/Tensorflow-Extended-tutorial/temp_/Trainer/model_run/22"
#         custom_properties {
#           key: "name"
#           value {
#             string_value: "model_run"
#           }
#         }
#         custom_properties {
#           key: "producer_component"
#           value {
#             string_value: "Trainer"
#           }
#         }
#         custom_properties {
#           key: "state"
#           value {
#             string_value: "published"
#           }
#         }
#         state: LIVE
#         , artifact_type: id: 18
#         name: "ModelRun"
#         )]
#             additional_properties: {}
#             additional_custom_properties: {}
#         ))

# %% [markdown]
# After the model training and exporting is completed, the component will register the path of the exported model with the metadata store. Downstream components can pick up the model for the model validation.
# The Trainer component is generic and not limited to running TensorFlow models. However, the components later in the pipeline expect that the model is saved in the TensorFlow SavedModel format. The SavedModel graph includes the Transform graph, so the data preprocessing steps are part of the model now.
#
# >**note:**<br>
# >> ***Overriding the Trainer Component’s Executor***<br>
# we override the Trainer component’s executor to enable the generic training entry point ```run_fn()``` function instead of the default ```trainer_fn()``` function, which only supports ```tf.Estimator``` models. In later notebook, we will see another Trainer executor, the ```ai_platform_trainer_executor.GenericExecutor```. This executor allows you to train models on Google Cloud’s AI Platform instead of inside your pipeline. This is an alternative if your model requires specific training hardware (e.g., GPUs or tensor processing units [TPUs]), which aren’t available in your pipeline environment.

# %% [markdown]
# To view TensorBoard in a notebook, we get the location of the model training logs and pass it to TensorBoard

# %%
model_dir = trainer.outputs['model'].get()[0].uri

# %tensorboard --logdir {model_dir}
# Out:
#       <iframe id="tensorboard-frame-cd83b33a4de74716" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-cd83b33a4de74716");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# ### Using the SavedModel outside a pipeline
#
# If we would like to inspect the exported SavedModel outside a TFX pipeline, we can load the model as a concrete function, which represents the graph of a single signature

# %%
model_path = trainer.outputs.model.get()[0].uri
model_path = os.path.join(model_path, 'serving_model_dir')
model = tf.saved_model.load(export_dir=model_path)
predict_fn = model.signatures["serving_default"]

# %% [markdown]
# With the model loaded as a concrete function, we can now perform predictions. The exported model expects the input data to be provided in the tf.Example data structure

# %%
example = tf.train.Example(features=tf.train.Features(feature={
                    "product": tf.train.Feature(bytes_list=tf.train.BytesList(value=['Debt collection'.encode()])),
                    "sub_product": tf.train.Feature(bytes_list=tf.train.BytesList(value=['I do not know'.encode()])),
                    "issue": tf.train.Feature(bytes_list=tf.train.BytesList(value=['Disclosure verification of debt'.encode()])),
                    "sub_issue": tf.train.Feature(bytes_list=tf.train.BytesList(value=['Right to dispute notice not received'.encode()])),
                    "state": tf.train.Feature(bytes_list=tf.train.BytesList(value=['NY'.encode()])),
                    "zip_code": tf.train.Feature(bytes_list=tf.train.BytesList(value=['113XX'.encode()])),
                    "company": tf.train.Feature(bytes_list=tf.train.BytesList(value=['Encore Capital Group'.encode()])),
                    "company_response": tf.train.Feature(bytes_list=tf.train.BytesList(value=['Closed with explanation'.encode()])),
                    "timely_response": tf.train.Feature(bytes_list=tf.train.BytesList(value=['Yes'.encode()])),
                    "consumer_complaint_narrative": tf.train.Feature(bytes_list=tf.train.BytesList(value=['I was denied employment because of a judgment against me.  I was/ am completely unaware of any hearing, never received any notice of collection of a debt by Midland LLC .  Midland LLC apparently took me to court somewhere without serving me any documents, and won a courts judgement.  I was never notified of any hearing, complaint, or received notice of collection of a debt by Midland LLC.'.encode()]))
}))

serialized_example = example.SerializeToString()
prediction = predict_fn(tf.constant([serialized_example]))['outputs'].numpy()[0,0]
print(f'predicted probability : {prediction}')
print(f'predicted value : {int(prediction)}')
# Out:
# predicted probability : 0.3753308951854706
# predicted value : 0

# %% [markdown]
# ## Distribution Strategies
#
# We done with the trainer component what if our model needs more computation power to be utilized to proceed training faseter?
#
# Therefore, TensorFlow provides distribution strategies for machine learning models that can’t be adequately trained on a single GPU. You might want to consider distribution strategies when you want to accelerate your training or you can’t fit the entire model into a single GPU. The strategies we describe here are abstractions to distribute the model parameters across multiple GPUs or even multiple servers. In general, there are two groups of
# strategies:
# - synchronous
# - asynchronous
#
# Under the synchronous strategies, all training workers train with different slices of the training data synchronously and then aggregate the gradients from all workers before updating the model.
#
# The asynchronous strategies train models independently with the entire dataset on differentworkers. Each worker updates the gradients of the model asynchronously, without waiting for the other workers to finish.
#
# Typically, synchronous strategies are coordinated  via all-reduce operations and asynchronous strategies through a parameter server architecture. A few synchronous and asynchronous strategies exist, and they have their benefits
# and drawbacks.
#
# Types of statergies in tensorflow are:
# - MirroredStrategy
# - TPUStrategy
# - MultiWorkerMirroredStrategy
# - CentralStorageStrategy
# - ParameterServerStrategy
#
# ### MirroredStrategy
# ```tf.distribute.MirroredStrategy``` supports synchronous distributed training on multiple GPUs on one machine. It creates one replica per GPU device. Each variable in the model is mirrored across all the replicas. Together, these variables form a single conceptual variable called MirroredVariable. These variables are kept in sync with each other by applying identical updates.
#
# Efficient all-reduce algorithms are used to communicate the variable updates across the devices. All-reduce aggregates tensors across all the devices by adding them up, and makes them available on each device.
#
#
# ### TPUStrategy
# ```tf.distribute.TPUStrategy``` lets you run your TensorFlow training on Tensor Processing Units (TPUs). TPUs are Google's specialized ASICs designed to dramatically accelerate machine learning workloads. They are available on Google Colab, the TensorFlow Research Cloud and Cloud TPU.
#
# In terms of distributed training architecture, TPUStrategy is the same ```MirroredStrategy```, it implements synchronous distributed training. TPUs provide their own implementation of efficient all-reduce and other collective operations across multiple TPU cores, which are used in TPUStrategy.
#
#
# ### MultiWorkerMirroredStrategy
# ```tf.distribute.MultiWorkerMirroredStrategy``` is very similar to MirroredStrategy. It implements synchronous distributed training across multiple workers, each with potentially multiple GPUs. Similar to tf.distribute.MirroredStrategy, it creates copies of all variables in the model on each device across all workers.
#
#
# ### ParameterServerStrategy
# Parameter server training is a common data-parallel method to scale up model training on multiple machines. A parameter server training cluster consists of workers and parameter servers. Variables are created on parameter servers and they are read and updated by workers in each step.
#
#
# ### CentralStorageStrategy
# ```tf.distribute.experimental.CentralStorageStrategy``` does synchronous training as well. Variables are not mirrored, instead they are placed on the CPU and operations are replicated across all local GPUs. If there is only one GPU, all variables and operations will be placed on that GPU.
#
# ![distribution_stratergy](image/distribution_stratergy.png)

# %% [markdown]
# An example of it here. We can apply the MirroredStrategy easily by adding a few lines before
# invoking our model creation and the subsequent model.compile() call.
#
# for that replace the ```model=get_model()``` (line 4) in ```run_n()``` with the code below
# ```
# mirrored_strategy = tf.distribute.MirroredStrategy()
# with mirrored_strategy.scope():
# model = get_model()
# ```
#
# This will help us the train our model in a distributed setup. we wrap the model creation and compilation with the Python manager (in our case, it all happens inside of the get_model() function). This will create and compile our model under the distribution scope of our choice. The ```MirroredStrategy``` will use all available GPUs of the instance. If you want to reduce the number of GPU instances being used, you can specify the GPUs to be used with the MirroredStrategy by changing the creation of the distribution strategy:
#
# ```
# mirrored_strategy = tf.distribute.MirroredStrategy(devices=["/gpu:0", "/gpu:1"]
# ```
#
# In this example, we specify two GPUs to be used for our training runs. These distribution strategies are useful for large training jobs that won’t fit on the memory of a single GPU.
#
# > note: <br>
# Batch Size Requirement When Using the MirroredStrategy.The MirroredStrategy expects that the batch size is proportional to the number of devices. For example, if you train with five GPUs, the batch size needs to be a multiple of the number of GPUs. Please keep this in mind when you set up your input_fn()

# %% [markdown]
# ## Hyperparameter Tuning in TFX Pipelines
# In a TFX pipeline, hyperparameter tuning takes in the data from the Transform com‐
# ponent and trains a variety of models to establish the best hyperparameters. The
# hyperparameters are then passed to the Trainer component, which then trains a final
# model using them.
# In this case, the model definition function (the get_model function in our example)
# needs to accept the hyperparameters as an input and build the model according to
# the specified hyperparameters. So, for example, the number of layers needs to be
# defined as an input argument.
